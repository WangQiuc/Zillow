# %% [markdown]
# Process Key Points:
# 1. Import and merge original data file. Deal with object/string type data.
# 2. Explore and select features based on their missing rates and importance ranks.
# 3. Transform data including encoding, normalization and scaling. Eliminate correlation and reduce dimension via PCA & LDA.
# 4. Fit model and tune parameters. Add extra features and prediction improves.

# %% [markdown]
# Prediction Summary:
# Sign of Logerror Classification

# %%
result = pd.DataFrame({'Adaboost': ['0.531 (+/-0.059)', '0.575 (+/-0.004)', '0.595 (+/-0.008)', '0.61 (+/- 0.09)', '0.65 (+/- 0.08)', '0.67 (+/- 0.04)', '3-20 sec', '<1 sec'], 
                       'Logistics Regression': ['0.528 (+/-0.055)', '0.576 (+/-0.009)', '0.594 (+/-0.009)', '0.58 (+/- 0.08)', '0.67 (+/- 0.04)', '0.67 (+/- 0.03)', '10-20 sec', '<1 sec'], 
                       'SVM': ['-', '0.574 (+/-0.008)', '0.593 (+/-0.005)', '-', '0.62 (+/- 0.08)', '0.62 (+/- 0.08)', '-', '2 min']}, 
                      index = ['Accuracy - Before LDA', 'Accuracy - After LDA', 'Accuracy - Add Prodesc', 'F1 Score - Before LDA', 'F1 Score - After LDA', 'F1 Score - Add Prodesc',
                               'Running Time - Before LDA', 'Running Time - After LDA'])
result
# Out:
#                                    Adaboost Logistics Regression  \
# Accuracy - Before LDA      0.531 (+/-0.059)     0.528 (+/-0.055)
# Accuracy - After LDA       0.575 (+/-0.004)     0.576 (+/-0.009)
# Accuracy - Add Prodesc     0.595 (+/-0.008)     0.594 (+/-0.009)
# F1 Score - Before LDA       0.61 (+/- 0.09)      0.58 (+/- 0.08)
# F1 Score - After LDA        0.65 (+/- 0.08)      0.67 (+/- 0.04)
# F1 Score - Add Prodesc      0.67 (+/- 0.04)      0.67 (+/- 0.03)
# Running Time - Before LDA          3-20 sec            10-20 sec
# Running Time - After LDA             <1 sec               <1 sec
#
#                                         SVM
# Accuracy - Before LDA                     -
# Accuracy - After LDA       0.574 (+/-0.008)
# Accuracy - Add Prodesc     0.593 (+/-0.005)
# F1 Score - Before LDA                     -
# F1 Score - After LDA        0.62 (+/- 0.08)
# F1 Score - Add Prodesc      0.62 (+/- 0.08)
# Running Time - Before LDA                 -
# Running Time - After LDA              2 min

# %% [markdown]
# Prediction Summary: Logerror Regression

# %%
result = pd.DataFrame({'Linear Regression': ['Poor'], 
                       'Lasso Regression': ['-0.053 (+/- 0.008)'], 
                       'Adaboost': ['-0.059 (+/- 0.008)']}, 
                      index = ['MAE'])
result
# Out:
#                Adaboost    Lasso Regression Linear Regression
# MAE  -0.059 (+/- 0.008)  -0.053 (+/- 0.008)              Poor

# %% [markdown]
# 1. Features with low missing rates tend to have higher importance.
# 2. Correlation elimination and dimension reduction via PCA & LDA improve prediction score and save running time.
# 3. Features related with tax, square size, room counts and location have higher coefficients in sign of logerror classification.
# 3. Features related with tax, square size and land use have higher coefficients in logerror regression.

# %% [markdown]
# # 1. Import Lib and Read Data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import model_selection, metrics, decomposition, linear_model, svm, ensemble, discriminant_analysis, preprocessing, feature_selection

# %matplotlib inline

# %% [markdown]
# ### 1.1. Merge label and feature data

# %% [markdown]
# Read original data

# %%
dp = pd.read_csv("./data/ref/origin/properties_2016.csv", low_memory=False)
dl = pd.read_csv("./data/ref/origin/train_2016_v2.csv", low_memory=False, parse_dates=['transactiondate'])
dic = pd.read_csv("./data/ref/origin/zillow_data_dictionary.csv", index_col=0, low_memory=False)

# %%
dl['logerrorsign'] = dl.logerror.apply(lambda x : 1 if x > 0 else -1)

# %%
d = dl.merge(dp, on = 'parcelid')
d.set_index('parcelid')
d.to_csv("./data/ref/data_merged.csv")

# %% [markdown]
# Merge training data with feature information

# %%
d = pd.read_csv("./data/ref/data_merged.csv", index_col=0, parse_dates=['transactiondate'])

# %%
d.head()
# Out:
#    parcelid  logerror transactiondate  logerrorsign  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01             1                    1.0
# 1  14366692   -0.1684      2016-01-01            -1                    NaN
# 2  12098116   -0.0040      2016-01-01            -1                    1.0
# 3  12643413    0.0218      2016-01-02             1                    1.0
# 4  14432541   -0.0050      2016-01-02            -1                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          3.0         2.0
# 3                       NaN           NaN          2.0         2.0
# 4                       NaN           NaN          2.5         4.0
#
#    buildingclasstypeid         ...           numberofstories  fireplaceflag  \
# 0                  NaN         ...                       NaN            NaN
# 1                  NaN         ...                       NaN            NaN
# 2                  NaN         ...                       NaN            NaN
# 3                  NaN         ...                       NaN            NaN
# 4                  NaN         ...                       2.0            NaN
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                    122754.0           360170.0          2015.0
# 1                    346458.0           585529.0          2015.0
# 2                     61994.0           119906.0          2015.0
# 3                    171518.0           244880.0          2015.0
# 4                    169574.0           434551.0          2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0               237416.0    6735.88                 NaN                 NaN
# 1               239071.0   10153.02                 NaN                 NaN
# 2                57912.0   11484.48                 NaN                 NaN
# 3                73362.0    3048.74                 NaN                 NaN
# 4               264977.0    5488.96                 NaN                 NaN
#
#    censustractandblock
# 0         6.037107e+13
# 1                  NaN
# 2         6.037464e+13
# 3         6.037296e+13
# 4         6.059042e+13
#
# [5 rows x 61 columns]

# %% [markdown]
# ### 1.2. Deal with String Type Data

# %%
# Convert True/False and Y/N into {1, -1}
d.fireplaceflag = d.fireplaceflag.apply(lambda x: 1 if x == True else 0)
d.hashottuborspa = d.hashottuborspa.apply(lambda x: 1 if x == True else 0)
d.taxdelinquencyflag = d.taxdelinquencyflag.apply(lambda x: 1 if x == 'Y' else 0)
dic.loc['fireplaceflag', 'Type'] = 'Categorical'
dic.loc['hashottuborspa', 'Type'] = 'Categorical'
dic.loc['taxdelinquencyflag', 'Type'] = 'Categorical'

# %%
d.propertyzoningdesc.head(10)
# Out:
# 0      LARS
# 1       NaN
# 2      PSR6
# 3      LAR3
# 4       NaN
# 5    HBR3YY
# 6     CORH*
# 7       NaN
# 8       NaN
# 9       NaN
# Name: propertyzoningdesc, dtype: object

# %%
# Transfer string into int code
lbl = preprocessing.LabelEncoder()
d.propertycountylandusecode = lbl.fit_transform(list(d.propertycountylandusecode.values))
d.propertyzoningdesc = lbl.fit_transform(list(d.propertyzoningdesc.values))

# %%
len(np.unique(d.propertyzoningdesc))
# Out:
# 1997

# %%
dic.loc[['propertycountylandusecode', 'propertyzoningdesc']]
# Out:
#                                                                  Description  \
# Feature
# propertycountylandusecode  County land use code i.e. it's zoning at the c...
# propertyzoningdesc         Description of the allowed land uses (zoning) ...
#
#                           Data Type  Predictor         Type
# Feature
# propertycountylandusecode    object       True  Categorical
# propertyzoningdesc           object       True  Categorical

# %%
dcor = pd.DataFrame({'propertycountylandusecode': d.propertycountylandusecode, 'propertyzoningdesc': d.propertyzoningdesc})
dcor.corr()
# Out:
#                            propertycountylandusecode  propertyzoningdesc
# propertycountylandusecode                   1.000000            0.758251
# propertyzoningdesc                          0.758251            1.000000

# %%
d.drop(['propertyzoningdesc'], axis=1, inplace=True)
dic.loc['propertyzoningdesc', 'Predictor'] = False

# %%
# Break transactiondate into month and weekday
d['month'] = d.transactiondate.dt.month
d['weekday'] = d.transactiondate.dt.weekday

# %%
# All samples' assessmentyears are equal to 2015 thus useless
len(np.unique(d.assessmentyear))
# Out:
# 1

# %%
d.drop(['assessmentyear'], axis=1, inplace=True)
dic.loc['assessmentyear', 'Predictor'] = False

# %%
d = d.set_index('parcelid')
d.to_csv("./data/data_raw.csv")
d.head()
# Out:
#           logerror transactiondate  logerrorsign  airconditioningtypeid  \
# parcelid
# 11016594    0.0276      2016-01-01             1                    1.0
# 14366692   -0.1684      2016-01-01            -1                    NaN
# 12098116   -0.0040      2016-01-01            -1                    1.0
# 12643413    0.0218      2016-01-02             1                    1.0
# 14432541   -0.0050      2016-01-02            -1                    NaN
#
#           architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# parcelid
# 11016594                       NaN           NaN          2.0         3.0
# 14366692                       NaN           NaN          3.5         4.0
# 12098116                       NaN           NaN          3.0         2.0
# 12643413                       NaN           NaN          2.0         2.0
# 14432541                       NaN           NaN          2.5         4.0
#
#           buildingclasstypeid  buildingqualitytypeid   ...     fireplaceflag  \
# parcelid                                               ...
# 11016594                  NaN                    4.0   ...                 0
# 14366692                  NaN                    NaN   ...                 0
# 12098116                  NaN                    4.0   ...                 0
# 12643413                  NaN                    4.0   ...                 0
# 14432541                  NaN                    NaN   ...                 0
#
#           structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# parcelid
# 11016594                    122754.0           360170.0
# 14366692                    346458.0           585529.0
# 12098116                     61994.0           119906.0
# 12643413                    171518.0           244880.0
# 14432541                    169574.0           434551.0
#
#           landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# parcelid
# 11016594               237416.0    6735.88                   0
# 14366692               239071.0   10153.02                   0
# 12098116                57912.0   11484.48                   0
# 12643413                73362.0    3048.74                   0
# 14432541               264977.0    5488.96                   0
#
#           taxdelinquencyyear  censustractandblock  month  weekday
# parcelid
# 11016594                 NaN         6.037107e+13      1        4
# 14366692                 NaN                  NaN      1        4
# 12098116                 NaN         6.037464e+13      1        4
# 12643413                 NaN         6.037296e+13      1        5
# 14432541                 NaN         6.059042e+13      1        5
#
# [5 rows x 60 columns]

# %% [markdown]
# Update dictionary

# %%
dic = dic.reset_index()

# %%
month_dic = pd.DataFrame([['month','Month of transaction', d.month.dtype,True,'Categorical']], index=[58], columns=['Feature', 'Description', 'Data Type', 'Predictor', 'Type'])
weekday_dic = pd.DataFrame([['weekday','Weekday of transaction', d.weekday.dtype,True,'Categorical']], index=[59], columns=['Feature', 'Description', 'Data Type', 'Predictor', 'Type'])
dic = dic.append(month_dic)
dic = dic.append(weekday_dic)

# %%
dic.to_csv("./data/ref/features_dictionary.csv")

# %% [markdown]
# # 2. Feature Exploration & Selection based on Missing & Importance

# %% [markdown]
# ### 2.1. Check Missing Rate

# %%
d = pd.read_csv("./data/data_raw.csv", index_col=0, low_memory=False)
dic = pd.read_csv("./data/ref/features_dictionary.csv", index_col=0, low_memory=False)

# %%
cat = (dic[(dic.Type == "Categorical") & dic.Predictor]).Feature.tolist()
num = (dic[(dic.Type == "Numerical") & dic.Predictor]).Feature.tolist()

# %%
d = d[['logerror', 'logerrorsign'] + cat + num]
d.head()
# Out:
#           logerror  logerrorsign  airconditioningtypeid  \
# parcelid
# 11016594    0.0276             1                    1.0
# 14366692   -0.1684            -1                    NaN
# 12098116   -0.0040            -1                    1.0
# 12643413    0.0218             1                    1.0
# 14432541   -0.0050            -1                    NaN
#
#           architecturalstyletypeid  buildingclasstypeid  decktypeid  \
# parcelid
# 11016594                       NaN                  NaN         NaN
# 14366692                       NaN                  NaN         NaN
# 12098116                       NaN                  NaN         NaN
# 12643413                       NaN                  NaN         NaN
# 14432541                       NaN                  NaN         NaN
#
#           fireplaceflag  hashottuborspa  heatingorsystemtypeid  pooltypeid10  \
# parcelid
# 11016594              0               0                    2.0           NaN
# 14366692              0               0                    NaN           NaN
# 12098116              0               0                    2.0           NaN
# 12643413              0               0                    2.0           NaN
# 14432541              0               0                    NaN           NaN
#
#                  ...          roomcnt  unitcnt  yardbuildingsqft17  \
# parcelid         ...
# 11016594         ...              0.0      1.0                 NaN
# 14366692         ...              0.0      NaN                 NaN
# 12098116         ...              0.0      1.0                 NaN
# 12643413         ...              0.0      1.0                 NaN
# 14432541         ...              8.0      NaN                 NaN
#
#           yardbuildingsqft26  yearbuilt  taxvaluedollarcnt  \
# parcelid
# 11016594                 NaN     1959.0           360170.0
# 14366692                 NaN     2014.0           585529.0
# 12098116                 NaN     1940.0           119906.0
# 12643413                 NaN     1987.0           244880.0
# 14432541                 NaN     1981.0           434551.0
#
#           structuretaxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  \
# parcelid
# 11016594                    122754.0               237416.0    6735.88
# 14366692                    346458.0               239071.0   10153.02
# 12098116                     61994.0                57912.0   11484.48
# 12643413                    171518.0                73362.0    3048.74
# 14432541                    169574.0               264977.0    5488.96
#
#           taxdelinquencyyear
# parcelid
# 11016594                 NaN
# 14366692                 NaN
# 12098116                 NaN
# 12643413                 NaN
# 14432541                 NaN
#
# [5 rows x 55 columns]

# %%
df = d.drop(['logerror', 'logerrorsign'], axis=1)
dm = df.isnull().sum()/len(d)
plt.ylabel('Missing Values Rate')
dm.sort_values(ascending=False).plot(figsize = (20, 4), kind='bar')

# %%
missing = pd.DataFrame()
missing['Feature'] = dm.index
missing['MissingRate'] = dm.values

# %% [markdown]
# ### 2.2. Fill Missing Values

# %% [markdown]
# Categorical and Numercial Features Exploration

# %%
print(cat)
print(num)
# Out:
# ['airconditioningtypeid', 'architecturalstyletypeid', 'buildingclasstypeid', 'decktypeid', 'fireplaceflag', 'hashottuborspa', 'heatingorsystemtypeid', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcounty', 'regionidcity', 'regionidneighborhood', 'storytypeid', 'typeconstructiontypeid', 'taxdelinquencyflag', 'month', 'weekday']
# ['basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'threequarterbathnbr', 'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet', 'finishedsquarefeet6', 'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'latitude', 'longitude', 'lotsizesquarefeet', 'numberofstories', 'poolcnt', 'poolsizesum', 'roomcnt', 'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt', 'taxvaluedollarcnt', 'structuretaxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyyear']

# %%
df[cat].hist(layout=(4, 5), figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026700730550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670078A780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026700569A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670061D780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670067E390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670067E3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267009AA9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026701453CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026704978C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267049B75C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026704F57240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026704F673C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670501FCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670507D9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267050EE780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026705153080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267051CB358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670522E2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026705269C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267052F6898>]], dtype=object)

# %%
df[num].hist(layout=(6, 6), figsize=(24, 18))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002670B515208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026704862438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267048A34A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000267048E1EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AA59438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AA59160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670A9A3F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AAB2F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AB07DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AB7FA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670ABE7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AC5E710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670ACC36A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670ACFDFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AD8AC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AD9B3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AE5A710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AEBA438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670AF2A1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AF88A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670AFFDD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B061CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B0A3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B115978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670B14FEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B1E3FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B1F5CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670B2B2A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BAA5860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BB13518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002670BB6FEB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BBF01D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BC54160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BC8EA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BD1C710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002670BD2FF60>]], dtype=object)

# %% [markdown]
# Fill categorical features' na with -1 as a new subgroup
#
# Fill poolcnt/fireplace/bathnbr/garage na with 0 since the na share fit the proporation of pool/fireplace/bathroom/garage ownership.
#
# Fill other numerical features' na with median since large value outliers existed.

# %%
for f in cat:
    d[f].fillna(-1, inplace=True)

# %%
for f in ['poolcnt', 'poolsizesum', 'fireplacecnt', 'fullbathcnt', 'threequarterbathnbr', 'garagetotalsqft', 'garagecarcnt']:
    d[f].fillna(0, inplace=True)

# %%
for f in num:
    d[f].fillna(d[f].median(), inplace=True)

# %%
d.isnull().sum()
# Out:
# logerror                        0
# logerrorsign                    0
# airconditioningtypeid           0
# architecturalstyletypeid        0
# buildingclasstypeid             0
# decktypeid                      0
# fireplaceflag                   0
# hashottuborspa                  0
# heatingorsystemtypeid           0
# pooltypeid10                    0
# pooltypeid2                     0
# pooltypeid7                     0
# propertycountylandusecode       0
# propertylandusetypeid           0
# regionidcounty                  0
# regionidcity                    0
# regionidneighborhood            0
# storytypeid                     0
# typeconstructiontypeid          0
# taxdelinquencyflag              0
# month                           0
# weekday                         0
# basementsqft                    0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# threequarterbathnbr             0
# finishedfloor1squarefeet        0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet6             0
# finishedsquarefeet12            0
# finishedsquarefeet13            0
# finishedsquarefeet15            0
# finishedsquarefeet50            0
# fireplacecnt                    0
# fullbathcnt                     0
# garagecarcnt                    0
# garagetotalsqft                 0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# numberofstories                 0
# poolcnt                         0
# poolsizesum                     0
# roomcnt                         0
# unitcnt                         0
# yardbuildingsqft17              0
# yardbuildingsqft26              0
# yearbuilt                       0
# taxvaluedollarcnt               0
# structuretaxvaluedollarcnt      0
# landtaxvaluedollarcnt           0
# taxamount                       0
# taxdelinquencyyear              0
# dtype: int64

# %%
d.to_csv('./data/data_filled.csv')

# %% [markdown]
# ### 2.3. Use random forest to check feature importance

# %%
x_train = d.drop(['logerror', 'logerrorsign'], axis=1)
y_train = d['logerror']
ys_train = d['logerrorsign']

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
rfr = RandomForestRegressor(n_estimators=30, max_features=None)
rfc = RandomForestClassifier(n_estimators=30, max_features=None)
rfr.fit(x_train, y_train)
rfc.fit(x_train, ys_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
feature_importance = rfr.feature_importances_
feature_importance_sign = rfc.feature_importances_
importance = pd.DataFrame()
importance['Feature'] = x_train.columns
importance['Importance'] = feature_importance
importance['ImportanceSign'] = feature_importance_sign

# %%
importance_missing = importance.merge(missing, on = 'Feature')
importance_missing = importance_missing.reset_index(drop=True).set_index('Feature')
importance_missing.sort_values(by='Importance', ascending=False)
# Out:
#                               Importance  ImportanceSign  MissingRate
# Feature
# structuretaxvaluedollarcnt      0.088036        0.083705     0.004209
# lotsizesquarefeet               0.084529        0.082466     0.112434
# latitude                        0.082493        0.084214     0.000000
# longitude                       0.079754        0.082196     0.000000
# taxamount                       0.078059        0.082281     0.000066
# taxvaluedollarcnt               0.069586        0.069318     0.000011
# landtaxvaluedollarcnt           0.068858        0.075933     0.000011
# yearbuilt                       0.058375        0.063847     0.008374
# calculatedfinishedsquarefeet    0.053065        0.052541     0.007322
# finishedsquarefeet12            0.050100        0.055347     0.051831
# month                           0.038805        0.040818     0.000000
# regionidcity                    0.032555        0.037058     0.019972
# regionidneighborhood            0.029746        0.028146     0.601086
# weekday                         0.025093        0.032365     0.000000
# bedroomcnt                      0.019267        0.016291     0.000000
# finishedsquarefeet15            0.012922        0.003095     0.960521
# garagetotalsqft                 0.011903        0.016754     0.668380
# propertycountylandusecode       0.010962        0.008524     0.000000
# buildingqualitytypeid           0.009118        0.006361     0.364564
# bathroomcnt                     0.007943        0.007007     0.000000
# calculatedbathnbr               0.007608        0.006647     0.013093
# fullbathcnt                     0.007316        0.005076     0.013093
# heatingorsystemtypeid           0.007308        0.006512     0.378787
# finishedfloor1squarefeet        0.006380        0.003496     0.924054
# propertylandusetypeid           0.005909        0.004082     0.000000
# airconditioningtypeid           0.005459        0.006242     0.681185
# taxdelinquencyyear              0.005101        0.001568     0.980249
# roomcnt                         0.005061        0.005956     0.000000
# finishedsquarefeet50            0.004388        0.003604     0.924054
# yardbuildingsqft17              0.004136        0.003904     0.970690
# pooltypeid7                     0.003478        0.002069     0.815043
# poolcnt                         0.002948        0.003873     0.801706
# finishedsquarefeet6             0.002835        0.000355     0.995336
# garagecarcnt                    0.002759        0.002607     0.668380
# unitcnt                         0.002487        0.000791     0.353608
# taxdelinquencyflag              0.002412        0.002002     0.000000
# fireplacecnt                    0.002338        0.002990     0.893581
# threequarterbathnbr             0.002178        0.002502     0.866973
# numberofstories                 0.002076        0.002216     0.772141
# hashottuborspa                  0.001106        0.001409     0.000000
# regionidcounty                  0.001085        0.000566     0.000000
# pooltypeid10                    0.001068        0.000894     0.987139
# buildingclasstypeid             0.000912        0.000003     0.999823
# decktypeid                      0.000477        0.000408     0.992711
# pooltypeid2                     0.000475        0.000290     0.986663
# poolsizesum                     0.000471        0.000852     0.989266
# architecturalstyletypeid        0.000376        0.000216     0.997109
# yardbuildingsqft26              0.000236        0.000095     0.998948
# basementsqft                    0.000177        0.000008     0.999524
# typeconstructiontypeid          0.000086        0.000197     0.996688
# fireplaceflag                   0.000086        0.000240     0.000000
# storytypeid                     0.000061        0.000036     0.999524
# finishedsquarefeet13            0.000040        0.000027     0.999634

# %%
features_to_plot = importance_missing.sort_values(by='Importance', ascending=False)
features_to_plot.Importance = importance_missing.Importance * 10
features_to_plot.ImportanceSign = importance_missing.ImportanceSign * 10
features_to_plot.plot(figsize=(15, 5), kind='bar')

# %% [markdown]
# ### 2.4. Apply RFE on Random Forest to Rank Features

# %%
rfe = feature_selection.RFE(estimator=rfr, verbose=1)
rfe_sign = feature_selection.RFE(estimator=rfc, verbose=1)

# %%
rfe.fit(x_train,y_train)
# Out:
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# RFE(estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=None, max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False),
#   n_features_to_select=None, step=1, verbose=1)

# %%
rfe_sign.fit(x_train,ys_train)
# Out:
# Fitting estimator with 53 features.
# Fitting estimator with 52 features.
# Fitting estimator with 51 features.
# Fitting estimator with 50 features.
# Fitting estimator with 49 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# RFE(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=30, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#   n_features_to_select=None, step=1, verbose=1)

# %%
feature_rank = pd.DataFrame({'Feature': x_train.columns, 'Rank': rfe.ranking_})
feature_rank['Feature'] = x_train.columns
feature_rank['Rank'] = rfe.ranking_
feature_rank['RankSign'] = rfe_sign.ranking_

# %% [markdown]
# Add importance & missing into dictionary

# %%
importance_missing = importance_missing.reset_index()

# %%
dic_importance = dic.merge(importance_missing, on = "Feature")
dic_importance = dic_importance.reset_index(drop=True)
dic_importance = dic_importance.merge(feature_rank, on = "Feature")
dic_importance = dic_importance.reset_index(drop=True)
dic_importance = dic_importance.set_index('Feature')

# %%
dic_importance.to_csv("./data/feature_dic.csv")

# %% [markdown]
# ### 2.5. Select Features

# %%
dic = pd.read_csv("./data/feature_dic.csv", low_memory=False)

# %%
dic[(dic.Rank < 11) & (dic.MissingRate >0.5)]
# Out:
#                      Feature  \
# 0      airconditioningtypeid
# 9        threequarterbathnbr
# 10  finishedfloor1squarefeet
# 12       finishedsquarefeet6
# 15      finishedsquarefeet15
# 16      finishedsquarefeet50
# 20              garagecarcnt
# 21           garagetotalsqft
# 28                   poolcnt
# 32               pooltypeid7
# 37      regionidneighborhood
# 42        yardbuildingsqft17
# 50        taxdelinquencyyear
#
#                                           Description Data Type  Predictor  \
# 0   Type of cooling system present in the home (if...   float64       True
# 9   Number of 3/4 bathrooms in house (shower + sin...   float64       True
# 10  Size of the finished living area on the first ...   float64       True
# 12                  Base unfinished and finished area   float64       True
# 15                                         Total area   float64       True
# 16  Size of the finished living area on the first ...   float64       True
# 20  Total number of garages on the lot including a...   float64       True
# 21  Total number of square feet of all garages on ...   float64       True
# 28                Number of pools on the lot (if any)   float64       True
# 32                               Pool without hot tub   float64       True
# 37      Neighborhood in which the property is located   float64       True
# 42                                     Patio in  yard   float64       True
# 50   Year for which the unpaid propert taxes were due   float64       True
#
#            Type  Importance  ImportanceSign  MissingRate  Rank  RankSign
# 0   Categorical    0.005459        0.006242     0.681185     4         1
# 9     Numerical    0.002178        0.002502     0.866973    10         9
# 10    Numerical    0.006380        0.003496     0.924054     1         1
# 12    Numerical    0.002835        0.000355     0.995336     9        19
# 15    Numerical    0.012922        0.003095     0.960521     1         6
# 16    Numerical    0.004388        0.003604     0.924054     1         4
# 20    Numerical    0.002759        0.002607     0.668380     7         7
# 21    Numerical    0.011903        0.016754     0.668380     1         1
# 28    Numerical    0.002948        0.003873     0.801706     5         1
# 32  Categorical    0.003478        0.002069     0.815043     8        12
# 37  Categorical    0.029746        0.028146     0.601086     1         1
# 42    Numerical    0.004136        0.003904     0.970690     6         3
# 50    Numerical    0.005101        0.001568     0.980249     3        13

# %%
dic[(dic.RankSign < 11) & (dic.MissingRate >0.5)]
# Out:
#                      Feature  \
# 0      airconditioningtypeid
# 9        threequarterbathnbr
# 10  finishedfloor1squarefeet
# 15      finishedsquarefeet15
# 16      finishedsquarefeet50
# 17              fireplacecnt
# 20              garagecarcnt
# 21           garagetotalsqft
# 28                   poolcnt
# 37      regionidneighborhood
# 42        yardbuildingsqft17
#
#                                           Description Data Type  Predictor  \
# 0   Type of cooling system present in the home (if...   float64       True
# 9   Number of 3/4 bathrooms in house (shower + sin...   float64       True
# 10  Size of the finished living area on the first ...   float64       True
# 15                                         Total area   float64       True
# 16  Size of the finished living area on the first ...   float64       True
# 17            Number of fireplaces in a home (if any)   float64       True
# 20  Total number of garages on the lot including a...   float64       True
# 21  Total number of square feet of all garages on ...   float64       True
# 28                Number of pools on the lot (if any)   float64       True
# 37      Neighborhood in which the property is located   float64       True
# 42                                     Patio in  yard   float64       True
#
#            Type  Importance  ImportanceSign  MissingRate  Rank  RankSign
# 0   Categorical    0.005459        0.006242     0.681185     4         1
# 9     Numerical    0.002178        0.002502     0.866973    10         9
# 10    Numerical    0.006380        0.003496     0.924054     1         1
# 15    Numerical    0.012922        0.003095     0.960521     1         6
# 16    Numerical    0.004388        0.003604     0.924054     1         4
# 17    Numerical    0.002338        0.002990     0.893581    13         5
# 20    Numerical    0.002759        0.002607     0.668380     7         7
# 21    Numerical    0.011903        0.016754     0.668380     1         1
# 28    Numerical    0.002948        0.003873     0.801706     5         1
# 37  Categorical    0.029746        0.028146     0.601086     1         1
# 42    Numerical    0.004136        0.003904     0.970690     6         3

# %% [markdown]
# Select feature with high rank and reasonable missing rate

# %%
selected_features = dic.Feature[dic.Rank < 11]
dsf = d[selected_features].drop(
    ['finishedfloor1squarefeet', 'finishedsquarefeet6', 'finishedsquarefeet15', 'finishedsquarefeet50', 'regionidneighborhood', 'yardbuildingsqft17', 'taxdelinquencyyear']
    , axis=1)
selected_features = dsf.columns
dsf.head()
# Out:
#           airconditioningtypeid  bathroomcnt  bedroomcnt  \
# parcelid
# 11016594                    1.0          2.0         3.0
# 14366692                   -1.0          3.5         4.0
# 12098116                    1.0          3.0         2.0
# 12643413                    1.0          2.0         2.0
# 14432541                   -1.0          2.5         4.0
#
#           buildingqualitytypeid  calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 11016594                    4.0                2.0                  0.0
# 14366692                    7.0                3.5                  1.0
# 12098116                    4.0                3.0                  0.0
# 12643413                    4.0                2.0                  0.0
# 14432541                    7.0                2.5                  1.0
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fullbathcnt  \
# parcelid
# 11016594                        1684.0                1684.0          2.0
# 14366692                        2263.0                2263.0          3.0
# 12098116                        2217.0                2217.0          3.0
# 12643413                         839.0                 839.0          2.0
# 14432541                        2283.0                2283.0          2.0
#
#           garagecarcnt   ...     propertylandusetypeid  regionidcity  roomcnt  \
# parcelid                 ...
# 11016594           0.0   ...                     261.0       12447.0      0.0
# 14366692           2.0   ...                     261.0       32380.0      0.0
# 12098116           0.0   ...                     261.0       47019.0      0.0
# 12643413           0.0   ...                     266.0       12447.0      0.0
# 14432541           2.0   ...                     261.0       17686.0      8.0
#
#           yearbuilt  taxvaluedollarcnt  structuretaxvaluedollarcnt  \
# parcelid
# 11016594     1959.0           360170.0                    122754.0
# 14366692     2014.0           585529.0                    346458.0
# 12098116     1940.0           119906.0                     61994.0
# 12643413     1987.0           244880.0                    171518.0
# 14432541     1981.0           434551.0                    169574.0
#
#           landtaxvaluedollarcnt  taxamount  month  weekday
# parcelid
# 11016594               237416.0    6735.88      1        4
# 14366692               239071.0   10153.02      1        4
# 12098116                57912.0   11484.48      1        4
# 12643413                73362.0    3048.74      1        5
# 14432541               264977.0    5488.96      1        5
#
# [5 rows x 28 columns]

# %%
selected_features_sign = dic.Feature[dic.RankSign < 11]
dsfs = d[selected_features_sign].drop(
    ['finishedfloor1squarefeet', 'finishedsquarefeet15', 'finishedsquarefeet50', 'regionidneighborhood', 'yardbuildingsqft17']
    , axis=1)
selected_features_sign = dsfs.columns
dsfs.head()
# Out:
#           airconditioningtypeid  bathroomcnt  bedroomcnt  \
# parcelid
# 11016594                    1.0          2.0         3.0
# 14366692                   -1.0          3.5         4.0
# 12098116                    1.0          3.0         2.0
# 12643413                    1.0          2.0         2.0
# 14432541                   -1.0          2.5         4.0
#
#           buildingqualitytypeid  calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 11016594                    4.0                2.0                  0.0
# 14366692                    7.0                3.5                  1.0
# 12098116                    4.0                3.0                  0.0
# 12643413                    4.0                2.0                  0.0
# 14432541                    7.0                2.5                  1.0
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fireplacecnt  \
# parcelid
# 11016594                        1684.0                1684.0           0.0
# 14366692                        2263.0                2263.0           0.0
# 12098116                        2217.0                2217.0           0.0
# 12643413                         839.0                 839.0           0.0
# 14432541                        2283.0                2283.0           0.0
#
#           fullbathcnt   ...     regionidcity  roomcnt  yearbuilt  \
# parcelid                ...
# 11016594          2.0   ...          12447.0      0.0     1959.0
# 14366692          3.0   ...          32380.0      0.0     2014.0
# 12098116          3.0   ...          47019.0      0.0     1940.0
# 12643413          2.0   ...          12447.0      0.0     1987.0
# 14432541          2.0   ...          17686.0      8.0     1981.0
#
#           taxvaluedollarcnt  structuretaxvaluedollarcnt  \
# parcelid
# 11016594           360170.0                    122754.0
# 14366692           585529.0                    346458.0
# 12098116           119906.0                     61994.0
# 12643413           244880.0                    171518.0
# 14432541           434551.0                    169574.0
#
#           landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  month  weekday
# parcelid
# 11016594               237416.0    6735.88                   0      1        4
# 14366692               239071.0   10153.02                   0      1        4
# 12098116                57912.0   11484.48                   0      1        4
# 12643413                73362.0    3048.74                   0      1        5
# 14432541               264977.0    5488.96                   0      1        5
#
# [5 rows x 30 columns]

# %%
print('Selected Features for Logerror: ')
print(selected_features.tolist())
print('Selected Features for Sign of Logerror: ')
print(selected_features_sign.tolist())
# Out:
# Selected Features for Logerror:
# ['airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'threequarterbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcity', 'roomcnt', 'yearbuilt', 'taxvaluedollarcnt', 'structuretaxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount', 'month', 'weekday']
# Selected Features for Sign of Logerror:
# ['airconditioningtypeid', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'threequarterbathnbr', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt', 'propertycountylandusecode', 'propertylandusetypeid', 'regionidcity', 'roomcnt', 'yearbuilt', 'taxvaluedollarcnt', 'structuretaxvaluedollarcnt', 'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyflag', 'month', 'weekday']

# %% [markdown]
# Among selected features, high correlation existed and PCA need to be applied later to eliminate correlation.

# %%
plt.figure(figsize =(20, 20))
plt.title('Logerror Selected Features Correlation')
sns.heatmap(dsf.corr(), annot=True)

# %%
plt.figure(figsize =(20, 20))
plt.title('Sign of Logerror Selected Features Correlation')
sns.heatmap(dsfs.corr(), annot=True)

# %%
ds = d[['logerror'] + selected_features.tolist()]
ds.to_csv("./data/logerror/data_selected.csv")
ds.head()
# Out:
#           logerror  airconditioningtypeid  bathroomcnt  bedroomcnt  \
# parcelid
# 11016594    0.0276                    1.0          2.0         3.0
# 14366692   -0.1684                   -1.0          3.5         4.0
# 12098116   -0.0040                    1.0          3.0         2.0
# 12643413    0.0218                    1.0          2.0         2.0
# 14432541   -0.0050                   -1.0          2.5         4.0
#
#           buildingqualitytypeid  calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 11016594                    4.0                2.0                  0.0
# 14366692                    7.0                3.5                  1.0
# 12098116                    4.0                3.0                  0.0
# 12643413                    4.0                2.0                  0.0
# 14432541                    7.0                2.5                  1.0
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fullbathcnt  \
# parcelid
# 11016594                        1684.0                1684.0          2.0
# 14366692                        2263.0                2263.0          3.0
# 12098116                        2217.0                2217.0          3.0
# 12643413                         839.0                 839.0          2.0
# 14432541                        2283.0                2283.0          2.0
#
#            ...     propertylandusetypeid  regionidcity  roomcnt  yearbuilt  \
# parcelid   ...
# 11016594   ...                     261.0       12447.0      0.0     1959.0
# 14366692   ...                     261.0       32380.0      0.0     2014.0
# 12098116   ...                     261.0       47019.0      0.0     1940.0
# 12643413   ...                     266.0       12447.0      0.0     1987.0
# 14432541   ...                     261.0       17686.0      8.0     1981.0
#
#           taxvaluedollarcnt  structuretaxvaluedollarcnt  \
# parcelid
# 11016594           360170.0                    122754.0
# 14366692           585529.0                    346458.0
# 12098116           119906.0                     61994.0
# 12643413           244880.0                    171518.0
# 14432541           434551.0                    169574.0
#
#           landtaxvaluedollarcnt  taxamount  month  weekday
# parcelid
# 11016594               237416.0    6735.88      1        4
# 14366692               239071.0   10153.02      1        4
# 12098116                57912.0   11484.48      1        4
# 12643413                73362.0    3048.74      1        5
# 14432541               264977.0    5488.96      1        5
#
# [5 rows x 29 columns]

# %%
dss = d[['logerrorsign'] + selected_features_sign.tolist()]
dss.to_csv("./data/sign/data_selected_sign.csv")
dss.head()
# Out:
#           logerrorsign  airconditioningtypeid  bathroomcnt  bedroomcnt  \
# parcelid
# 11016594             1                    1.0          2.0         3.0
# 14366692            -1                   -1.0          3.5         4.0
# 12098116            -1                    1.0          3.0         2.0
# 12643413             1                    1.0          2.0         2.0
# 14432541            -1                   -1.0          2.5         4.0
#
#           buildingqualitytypeid  calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 11016594                    4.0                2.0                  0.0
# 14366692                    7.0                3.5                  1.0
# 12098116                    4.0                3.0                  0.0
# 12643413                    4.0                2.0                  0.0
# 14432541                    7.0                2.5                  1.0
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fireplacecnt  \
# parcelid
# 11016594                        1684.0                1684.0           0.0
# 14366692                        2263.0                2263.0           0.0
# 12098116                        2217.0                2217.0           0.0
# 12643413                         839.0                 839.0           0.0
# 14432541                        2283.0                2283.0           0.0
#
#            ...     regionidcity  roomcnt  yearbuilt  taxvaluedollarcnt  \
# parcelid   ...
# 11016594   ...          12447.0      0.0     1959.0           360170.0
# 14366692   ...          32380.0      0.0     2014.0           585529.0
# 12098116   ...          47019.0      0.0     1940.0           119906.0
# 12643413   ...          12447.0      0.0     1987.0           244880.0
# 14432541   ...          17686.0      8.0     1981.0           434551.0
#
#           structuretaxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  \
# parcelid
# 11016594                    122754.0               237416.0    6735.88
# 14366692                    346458.0               239071.0   10153.02
# 12098116                     61994.0                57912.0   11484.48
# 12643413                    171518.0                73362.0    3048.74
# 14432541                    169574.0               264977.0    5488.96
#
#           taxdelinquencyflag  month  weekday
# parcelid
# 11016594                   0      1        4
# 14366692                   0      1        4
# 12098116                   0      1        4
# 12643413                   0      1        5
# 14432541                   0      1        5
#
# [5 rows x 31 columns]

# %% [markdown]
# # 3. Data Preprossing

# %%
d = pd.read_csv("./data/logerror/data_selected.csv", index_col=0, low_memory=False)
ds = pd.read_csv("./data/sign/data_selected_sign.csv", index_col=0, low_memory=False)
dic = pd.read_csv("./data/feature_dic.csv", low_memory=False)

# %%
dsorted = d.sort_values(by='logerror')
low = int(len(dsorted) * 0.01)
upper = int(len(dsorted) * 0.99)
d = dsorted[low: upper].sort_index()

# %%
# d = d.drop(['propertycountylandusecode', 'propertylandusetypeid', 'regionidcity'], axis=1)

# %%
df = d.drop(['logerror'], axis=1)
dfs = ds.drop(['logerrorsign'], axis=1)

# %%
cat_list = (dic[(dic.Type == "Categorical") & dic.Predictor]).Feature.tolist()
cat, cats, num, nums = [], [], [], []
for col in df.columns:
    cat.append(col) if col in cat_list else num.append(col)
for col in dfs.columns:
    cats.append(col) if col in cat_list else nums.append(col)

# %% [markdown]
# ### 3.1. Data Transformation

# %% [markdown]
# Encode

# %%
print('Logerror')
for f in cat:
    print('%s: %d' %(f, len(np.unique(df[f]))))
print('\nSign of Logerror')
for f in cats:
    print('%s: %d' %(f, len(np.unique(dfs[f]))))
# Out:
# Logerror
# airconditioningtypeid: 7
# heatingorsystemtypeid: 13
# pooltypeid7: 2
# month: 12
# weekday: 7
#
# Sign of Logerror
# airconditioningtypeid: 7
# hashottuborspa: 2
# heatingorsystemtypeid: 13
# propertycountylandusecode: 78
# propertylandusetypeid: 14
# regionidcity: 178
# taxdelinquencyflag: 2
# month: 12
# weekday: 7

# %%
df_encoded = pd.get_dummies(df, columns=cat, drop_first=True)
dfs_encoded = pd.get_dummies(dfs, columns=cats, drop_first=True)

# %% [markdown]
# Normlization

# %%
# Normlize skewed distributed features
df_norm = df_encoded.copy()
for n in num:
    if n not in ['latitude', 'longitude', 'yearbuilt']:
        df_norm[n] = np.log(df_encoded[n] + 1)

# %%
dfs_norm = dfs_encoded.copy()
for n in nums:
    if n not in ['latitude', 'longitude', 'yearbuilt']:
        dfs_norm[n] = np.log(dfs_encoded[n] + 1)

# %% [markdown]
# Scaling

# %%
from sklearn import preprocessing
sc = preprocessing.StandardScaler()
df_scaled = pd.DataFrame(sc.fit_transform(df_norm), index = df_norm.index, columns = df_norm.columns)
dfs_scaled = pd.DataFrame(sc.fit_transform(dfs_norm), index = dfs_norm.index, columns = dfs_norm.columns)

# %%
d_transformed = pd.concat([d.logerror, df_scaled], axis=1)
d_transformed.head()
# Out:
#           logerror  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# parcelid
# 10711738    0.0276     0.799182    0.829072              -1.030028
# 10711755   -0.0182     0.799182    0.115252              -1.030028
# 10711805   -0.1009    -0.147341    0.115252              -1.030028
# 10711816   -0.0121    -0.147341    0.829072              -1.030028
# 10711858   -0.0481    -0.147341    0.829072              -1.030028
#
#           calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 10711738           0.830957            -0.393291
# 10711755           0.830957            -0.393291
# 10711805          -0.210244            -0.393291
# 10711816          -0.210244            -0.393291
# 10711858          -0.210244            -0.393291
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fullbathcnt  \
# parcelid
# 10711738                      1.054812              1.122819     0.871515
# 10711755                     -0.010179              0.024356     0.871515
# 10711805                      0.938050              1.002387    -0.078573
# 10711816                      0.762589              0.821412    -0.078573
# 10711858                      0.374672              0.421303    -0.078573
#
#           garagecarcnt    ...       month_9  month_10  month_11  month_12  \
# parcelid                  ...
# 10711738     -0.685964    ...     -0.344485 -0.241646  -0.14399 -0.139888
# 10711755     -0.685964    ...     -0.344485 -0.241646  -0.14399 -0.139888
# 10711805     -0.685964    ...     -0.344485 -0.241646  -0.14399 -0.139888
# 10711816     -0.685964    ...     -0.344485 -0.241646  -0.14399 -0.139888
# 10711858     -0.685964    ...     -0.344485 -0.241646  -0.14399 -0.139888
#
#           weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6
# parcelid
# 10711738   2.095055  -0.493226  -0.511402  -0.603267  -0.050382  -0.099888
# 10711755   2.095055  -0.493226  -0.511402  -0.603267  -0.050382  -0.099888
# 10711805   2.095055  -0.493226  -0.511402  -0.603267  -0.050382  -0.099888
# 10711816   2.095055  -0.493226  -0.511402  -0.603267  -0.050382  -0.099888
# 10711858  -0.477314  -0.493226  -0.511402   1.657642  -0.050382  -0.099888
#
# [5 rows x 57 columns]

# %%
ds_transformed = pd.concat([ds.logerrorsign, dfs_scaled], axis=1)
ds_transformed.head()
# Out:
#           logerrorsign  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# parcelid
# 11016594             1    -0.141558    0.117146              -1.031873
# 14366692            -1     1.178865    0.824170               0.525808
# 12098116            -1     0.795297   -0.794365              -1.031873
# 12643413             1    -0.141558   -0.794365              -1.031873
# 14432541            -1     0.360443    0.824170               0.525808
#
#           calculatedbathnbr  threequarterbathnbr  \
# parcelid
# 11016594          -0.207276            -0.391002
# 14366692           1.251363             2.533662
# 12098116           0.827645            -0.391002
# 12643413          -0.207276            -0.391002
# 14432541           0.347273             2.533662
#
#           calculatedfinishedsquarefeet  finishedsquarefeet12  fireplacecnt  \
# parcelid
# 11016594                      0.120643              0.161216     -0.335107
# 14366692                      0.788363              0.851061     -0.335107
# 12098116                      0.741958              0.803118     -0.335107
# 12643413                     -1.453032             -1.464602     -0.335107
# 14432541                      0.808245              0.871602     -0.335107
#
#           fullbathcnt    ...       month_9  month_10  month_11  month_12  \
# parcelid                 ...
# 11016594    -0.074042    ...     -0.344455 -0.241554 -0.143683 -0.140149
# 14366692     0.866373    ...     -0.344455 -0.241554 -0.143683 -0.140149
# 12098116     0.866373    ...     -0.344455 -0.241554 -0.143683 -0.140149
# 12643413    -0.074042    ...     -0.344455 -0.241554 -0.143683 -0.140149
# 14432541    -0.074042    ...     -0.344455 -0.241554 -0.143683 -0.140149
#
#           weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6
# parcelid
# 11016594  -0.477088  -0.493119  -0.512209   1.659550  -0.049986   -0.09933
# 14366692  -0.477088  -0.493119  -0.512209   1.659550  -0.049986   -0.09933
# 12098116  -0.477088  -0.493119  -0.512209   1.659550  -0.049986   -0.09933
# 12643413  -0.477088  -0.493119  -0.512209  -0.602573  20.005555   -0.09933
# 14432541  -0.477088  -0.493119  -0.512209  -0.602573  20.005555   -0.09933
#
# [5 rows x 326 columns]

# %%
d_transformed.to_csv('./data/logerror/data_transformed.csv')
ds_transformed.to_csv('./data/sign/data_transformed_sign.csv')

# %% [markdown]
# ### 3.2. Correlation Elimination & Dimension Reduction by PCA & LDA for Sign of Logerror

# %%
d = pd.read_csv('./data/logerror/data_transformed.csv', index_col=0, low_memory=False)
ds = pd.read_csv('./data/sign/data_transformed_sign.csv', index_col=0, low_memory=False)

# %%
df = d.drop(['logerror'], axis=1)
dfs = ds.drop(['logerrorsign'], axis=1)
dt = d.logerror
dts = ds.logerrorsign

# %%
pca = decomposition.PCA()
pcas = decomposition.PCA()
lda = discriminant_analysis.LinearDiscriminantAnalysis()

# %%
df_pca = pca.fit_transform(df)
dfs_pca = pcas.fit_transform(dfs)

# %%
plt.plot(pca.explained_variance_ratio_)

# %%
plt.plot(pcas.explained_variance_ratio_)

# %%
df_pca = pd.DataFrame(df_pca, index=d.index)
dfs_pca = pd.DataFrame(dfs_pca, index=ds.index)

# %%
dfs_lda = lda.fit_transform(dfs_pca, dts)
dfs_lda = pd.DataFrame(dfs_lda, index=ds.index, columns=['LDA'])

# %%
df_pca.to_csv("./data/logerror/df_pca.csv")
dfs_lda.to_csv("./data/sign/df_lda_sign.csv")

# %% [markdown]
# # 4. Modeling for Sign of Logerror

# %% [markdown]
# ### 4.1. Data Split

# %%
d = pd.read_csv('./data/sign/data_transformed_sign.csv', index_col=0, low_memory=False)
y = d.logerrorsign
#Use Scaled data
x = d.drop(['logerrorsign'], axis=1)
#Use Scalded and LDA data
xl = pd.read_csv("./data/sign/df_lda_sign.csv", index_col=0, low_memory=False)

# %%
train_id, test_id = model_selection.train_test_split(d.index, test_size=0.2)

# %%
x_train = x.loc[train_id]
x_test = x.loc[test_id]
y_train = y.loc[train_id]
y_test = y.loc[test_id]
xl_train = xl.loc[train_id]
xl_test = xl.loc[test_id]

# %% [markdown]
# ### 4.2. Fit Model

# %% [markdown]
# AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators=100, learning_rate=0.5)
adal = ensemble.AdaBoostClassifier(n_estimators=15, learning_rate=0.75)

# %%
ada.fit(x_train, y_train)
adal.fit(xl_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=0.75, n_estimators=15, random_state=None)

# %%
y_pred = ada.predict(x_test)
yl_pred = adal.predict(xl_test)

# %%
print('Non LDA Accuracy:')
scores = model_selection.cross_val_score(ada, x, y, cv=5, verbose=1, n_jobs=5, scoring='f1')
print("Cross-Validated F1-Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
print()
print('LDA Accuracy:')
scores = model_selection.cross_val_score(adal, xl, y, cv=5, verbose=1, n_jobs=5, scoring='f1')
print("Cross-Validated F1-Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# Non LDA Accuracy:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   44.6s remaining:  1.1min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   52.8s finished
# Cross-Validated F1-Score: 0.61 (+/- 0.09)
#
# LDA Accuracy:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    7.8s remaining:   11.7s
# Cross-Validated F1-Score: 0.65 (+/- 0.08)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   15.7s finished

# %%
print("None LDA Report: ")
print(metrics.classification_report(y_test, y_pred, target_names=['Lower','Higher']))
print("LDA Report: ")
print(metrics.classification_report(y_test, yl_pred, target_names=['Lower','Higher']))
# Out:
# None LDA Report:
#              precision    recall  f1-score   support
#
#       Lower       0.55      0.27      0.36      8040
#      Higher       0.59      0.82      0.68     10072
#
# avg / total       0.57      0.58      0.54     18112
#
# LDA Report:
#              precision    recall  f1-score   support
#
#       Lower       0.55      0.31      0.40      8040
#      Higher       0.59      0.80      0.68     10072
#
# avg / total       0.57      0.58      0.55     18112

# %% [markdown]
# Logistic Regression

# %%
lr = linear_model.LogisticRegression(C=0.01)
lrl = linear_model.LogisticRegression(C=0.01)

# %%
lr.fit(x_train, y_train)
lrl.fit(xl_train, y_train)
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = lr.predict(x_test)
yl_pred = lrl.predict(xl_test)

# %%
print('Non LDA Accuracy:')
scores = model_selection.cross_val_score(lr, x, y, cv=5, verbose=1, n_jobs=5, scoring="f1")
print("Cross-Validated F1-Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() ))
print()
print('LDA Accuracy:')
scores = model_selection.cross_val_score(lrl, xl, y, cv=5, verbose=1, n_jobs=5, scoring="f1")
print("Cross-Validated F1-Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() ))
# Out:
# Non LDA Accuracy:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   22.0s remaining:   33.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   31.2s finished
# Cross-Validated F1-Score: 0.58 (+/- 0.08)
#
# LDA Accuracy:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    7.5s remaining:   11.3s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   15.5s finished
# Cross-Validated F1-Score: 0.67 (+/- 0.04)

# %%
print("None LDA Report: ")
print(metrics.classification_report(y_test, y_pred, target_names=['Lower','Higher']))
print("LDA Report: ")
print(metrics.classification_report(y_test, yl_pred, target_names=['Lower','Higher']))
# Out:
# None LDA Report:
#              precision    recall  f1-score   support
#
#       Lower       0.53      0.31      0.40      8084
#      Higher       0.58      0.78      0.67     10020
#
# avg / total       0.56      0.57      0.55     18104
#
# LDA Report:
#              precision    recall  f1-score   support
#
#       Lower       0.55      0.32      0.41      8084
#      Higher       0.59      0.79      0.67     10020
#
# avg / total       0.57      0.58      0.55     18104

# %%
lr.coef_[0]
# Out:
# array([  7.04828653e-03,  -7.15917876e-02,  -2.14440997e-03,
#         -8.46614051e-02,   3.08269965e-02,   2.14575771e-01,
#          1.00923219e-01,  -9.95532503e-03,   1.33623563e-01,
#         -1.04130663e-01,  -4.05423113e-02,  -4.66383839e-02,
#         -7.30026597e-02,  -1.26587352e-02,  -9.60197350e-02,
#          7.90766711e-03,   3.03015407e-02,   2.70521201e-01,
#         -8.62507845e-02,   3.15227476e-02,  -3.43730865e-01,
#          3.70429410e-02,   1.85227359e-02,  -2.56182409e-03,
#          1.74733941e-02,   1.50100679e-02,   6.84181891e-03,
#         -6.59268590e-02,   8.06315017e-03,  -1.57657991e-02,
#          6.07791454e-03,   3.74442045e-02,  -2.49961460e-02,
#         -1.88708295e-02,  -1.60851651e-02,  -1.25754293e-02,
#         -5.24350164e-04,  -4.61128383e-03,  -1.34262041e-02,
#         -2.35494954e-02,   1.69892684e-02,  -4.60853388e-02,
#         -5.48243438e-02,   2.33533640e-02,  -5.45891138e-03,
#          8.57308740e-03,  -1.17354828e-02,  -3.63210095e-04,
#          3.74907842e-02,  -2.91822380e-02,   4.81135542e-02,
#          3.40614792e-03,  -2.84737475e-02,   3.09642138e-03,
#          9.07868140e-03,  -1.32959885e-02,  -5.04861489e-03,
#          1.43683175e-02,  -1.93356038e-02,   1.70401808e-02,
#          2.49965564e-02,  -6.50368582e-03,   1.66915709e-02,
#         -1.86054779e-02,  -1.75554438e-02,  -1.69729831e-02,
#          8.75913795e-03,  -2.70649483e-03,   3.36571688e-03,
#          3.16739254e-02,  -6.86472448e-04,  -1.83938553e-02,
#         -1.29369971e-02,  -1.75952200e-02,   1.73777746e-02,
#         -2.48253807e-02,  -1.29664835e-02,   2.75282901e-02,
#          1.76755849e-02,   9.51413889e-03,  -2.60401240e-02,
#         -1.11815868e-02,   5.49033766e-02,  -3.71274507e-02,
#         -2.76614778e-02,   4.14995404e-04,  -1.83919558e-02,
#          3.55089237e-03,  -8.93669044e-03,  -4.00486202e-02,
#          1.50163421e-03,  -2.72657523e-02,  -5.55334549e-03,
#         -7.63687470e-04,  -1.70976206e-02,   8.51800862e-03,
#         -1.02640710e-02,   6.56716759e-02,  -1.94777925e-04,
#         -4.08283075e-03,   6.11936542e-03,   1.49667971e-02,
#         -1.11497461e-02,   5.37172458e-03,   1.51748811e-02,
#         -2.19692705e-03,  -2.38735020e-03,   4.09795680e-02,
#         -1.83174409e-02,  -1.66595660e-02,   7.10177809e-03,
#         -8.02816429e-03,  -1.73486072e-02,   3.08446356e-03,
#         -6.86472448e-04,  -7.65068836e-03,  -1.72487678e-02,
#          8.51800862e-03,  -1.96113512e-02,  -1.55373057e-02,
#         -3.22688916e-02,   7.90147281e-03,   3.44836106e-03,
#          3.52769364e-02,   9.88581368e-03,  -7.63687470e-04,
#          5.15612168e-03,   3.40614792e-03,  -1.18389712e-03,
#         -5.55334549e-03,   6.34678794e-03,  -4.29472465e-02,
#         -2.12079133e-02,  -3.14483812e-02,  -3.33893564e-02,
#         -1.84816352e-02,  -8.60539667e-04,   3.25314540e-03,
#         -1.34957452e-02,   7.60107017e-03,   1.46636803e-02,
#         -2.40306250e-02,  -4.05921776e-03,  -2.03141864e-02,
#          1.13641745e-02,  -6.17662637e-03,   2.61688113e-02,
#         -3.11413663e-03,  -8.31703620e-03,  -8.05372827e-02,
#          7.36711057e-03,  -1.21215699e-02,   8.19685997e-03,
#         -1.30576151e-02,  -7.62835775e-03,   6.01358729e-03,
#         -1.88683064e-03,  -6.82287124e-03,  -5.58514198e-03,
#         -1.25416617e-02,  -2.44484432e-02,  -1.09857367e-02,
#          1.11932736e-02,   2.64691773e-02,   2.19513968e-03,
#          2.19509710e-02,  -1.67031406e-02,   6.23871749e-03,
#         -8.65083587e-03,   1.48512077e-02,  -1.52544034e-02,
#          1.59320739e-03,   5.15669786e-03,   1.72499588e-04,
#          2.59062436e-03,  -1.65310605e-02,   6.92292373e-03,
#         -3.14142384e-02,   4.34334325e-03,   1.68457652e-02,
#          1.41809954e-02,  -3.13791532e-02,   3.34783639e-03,
#          2.01543579e-02,  -8.02174601e-04,   2.12232102e-02,
#         -2.67218835e-02,  -1.13462027e-02,  -1.04237842e-03,
#          6.80198125e-03,   4.22673395e-03,   6.00272677e-04,
#          6.18220269e-04,   1.45965156e-02,  -2.62912718e-03,
#          1.76225802e-02,   3.74213696e-03,   1.26130150e-02,
#         -2.33339779e-02,   1.13362165e-02,   2.60513079e-03,
#          2.26245364e-02,  -3.50444939e-02,   2.34845337e-03,
#          1.42537230e-03,  -8.44930219e-03,  -1.88260021e-03,
#          2.39366896e-02,  -1.07100931e-02,   1.46936498e-03,
#         -9.77108108e-03,  -3.26634098e-03,  -1.32531325e-02,
#         -1.26378926e-02,   7.39295800e-03,   8.31953246e-03,
#         -2.06171228e-02,  -1.20511717e-02,  -5.13503209e-03,
#         -2.17103220e-02,   4.45658703e-03,   1.54127987e-03,
#          2.93537333e-02,   1.68133488e-02,   7.53678748e-04,
#          1.74262380e-02,  -2.30932653e-02,  -2.46184587e-03,
#         -1.61332386e-02,   5.02777722e-03,   1.95480480e-02,
#         -2.17342530e-02,   5.44753516e-03,   1.60598441e-02,
#         -2.16597657e-03,  -7.77202708e-03,  -2.47007893e-02,
#          6.84723148e-03,   1.14477527e-02,  -6.56385290e-03,
#         -4.29784807e-03,   6.02596141e-03,  -3.53153040e-02,
#         -5.17142037e-03,  -9.73379193e-03,  -1.99013661e-02,
#          5.84632461e-03,  -4.45679313e-03,  -9.01464890e-03,
#         -1.86905850e-02,  -2.59646630e-02,  -6.83074831e-03,
#         -3.30429180e-02,  -2.35497385e-02,   3.14442517e-03,
#         -3.03653813e-03,  -2.49597970e-02,  -9.73857872e-03,
#         -2.93789716e-02,  -4.32406864e-03,  -1.35522529e-02,
#         -6.67158212e-03,   1.47389479e-03,  -2.63777404e-02,
#         -6.56476532e-03,   4.14992808e-03,   3.28054548e-02,
#          3.09379865e-02,  -2.96940717e-02,   1.73560702e-03,
#          6.31021912e-03,   1.63963379e-02,   1.13437194e-02,
#          1.60448725e-02,   5.64467011e-03,  -7.18996393e-03,
#         -1.64391045e-02,   1.02561344e-02,   1.26924078e-02,
#         -3.81067302e-03,  -3.19953157e-02,  -4.76241177e-03,
#         -1.13820469e-02,  -3.09486325e-02,   5.00136524e-04,
#         -1.64041237e-02,   1.66705411e-02,  -2.06655178e-02,
#          2.90278337e-03,  -4.99985130e-03,   1.52825799e-02,
#          3.48145216e-03,   4.06237761e-03,   7.63618753e-03,
#          5.71220011e-03,  -2.54304395e-03,  -2.85680990e-02,
#         -3.49672224e-02,   1.06999020e-02,  -7.28835053e-03,
#         -2.60011035e-02,   4.58297977e-03,  -1.72710789e-02,
#         -8.47032944e-03,  -8.66757888e-03,  -1.34189888e-02,
#         -7.32001192e-03,   3.13335312e-02,   1.05650493e-03,
#         -9.76037610e-02,  -7.97318606e-02,  -7.49637871e-02,
#         -6.76288715e-02,  -5.74265300e-02,  -4.75615489e-02,
#          1.04198112e-02,   1.44986785e-02,   7.16134566e-03,
#          1.25653624e-02,   1.75207837e-02,   7.02174593e-03,
#         -2.23872466e-03,   4.47101776e-03,   1.07740263e-02,
#         -1.68518902e-02])

# %%
print('Intercept:',lr.intercept_)
print('Coefficients:')
coefs_df = pd.DataFrame(index=x_train.columns, data=lr.coef_[0], columns=['coef']);
coefs_df.sort_values('coef', ascending=False).plot.barh(figsize=(20, 100));
# Out:
# Intercept: [ 0.20625499]
# Coefficients:

# %%
print(coefs_df.sort_values('coef', ascending=False).head(20))
print(coefs_df.sort_values('coef', ascending=False).tail(20))
# Out:
#                                   coef
# taxvaluedollarcnt             0.270521
# calculatedfinishedsquarefeet  0.214576
# fullbathcnt                   0.133624
# finishedsquarefeet12          0.100923
# propertycountylandusecode_58  0.065672
# propertycountylandusecode_43  0.054903
# propertycountylandusecode_11  0.048114
# propertycountylandusecode_68  0.040980
# propertycountylandusecode_9   0.037491
# heatingorsystemtypeid_7.0     0.037444
# airconditioningtypeid_1.0     0.037043
# propertylandusetypeid_263.0   0.035277
# regionidcity_50749.0          0.032805
# propertycountylandusecode_30  0.031674
# landtaxvaluedollarcnt         0.031523
# taxdelinquencyflag_1          0.031334
# regionidcity_51239.0          0.030938
# threequarterbathnbr           0.030827
# yearbuilt                     0.030302
# regionidcity_33837.0          0.029354
#                                  coef
# garagetotalsqft             -0.040542
# regionidcity_4406.0         -0.042947
# propertycountylandusecode_2 -0.046085
# latitude                    -0.046638
# month_8                     -0.047562
# propertycountylandusecode_3 -0.054824
# month_7                     -0.057427
# hashottuborspa_1            -0.065927
# month_6                     -0.067629
# bedroomcnt                  -0.071592
# longitude                   -0.073003
# month_5                     -0.074964
# month_4                     -0.079732
# regionidcity_12447.0        -0.080537
# calculatedbathnbr           -0.084661
# structuretaxvaluedollarcnt  -0.086251
# poolcnt                     -0.096020
# month_3                     -0.097604
# garagecarcnt                -0.104131
# taxamount                   -0.343731

# %% [markdown]
# Features related with tax, square sizes room counts and location have higher coefficients.

# %% [markdown]
# SVM

# %%
svm_model = svm.SVC(C=0.5, kernel='rbf', gamma='auto')

# %%
svm_model.fit(xl_train, y_train)
# Out:
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
yl_pred = svm_model.predict(xl_test)

# %%
print('LDA Accuracy:')
scores = model_selection.cross_val_score(svm_model, xl, y, cv=5, verbose=1, n_jobs=5, scoring="f1")
print("Cross-Validated F1-Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() ))
# Out:
# LDA Accuracy:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  4.9min remaining:  7.3min
# Cross-Validated F1-Score: 0.67 (+/- 0.04)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  5.2min finished

# %%
print("LDA Report: ")
print(metrics.classification_report(y_test, yl_pred, target_names=['Lower','Higher']))
# Out:
# LDA Report:
#              precision    recall  f1-score   support
#
#       Lower       0.55      0.31      0.40      8162
#      Higher       0.58      0.79      0.67      9927
#
# avg / total       0.57      0.57      0.55     18089

# %% [markdown]
# ### 4.3. Parameter Tunning & Cross Validation

# %%
def report(clf):
    print("Best parameters set found on development set:")
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print(("%0.3f (+/-%0.03f) for %r")
              % (mean, std * 2, params))
    print()
    print("Detailed classification report:")
    print()
    scores = model_selection.cross_val_score(clf.best_estimator_, x, y, cv=5, verbose=1, n_jobs=5, scoring="f1")
    print("Cross-Validated F1-Score: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() ))
    print()

# %%
tuned_parameters = {'n_estimators': [15, 30, 50, 100], 'learning_rate': [0.5, 0.75, 1.0]}
ada_search = model_selection.RandomizedSearchCV(ensemble.AdaBoostClassifier(), verbose= 2, param_distributions=tuned_parameters, n_iter=12)
adal_search = model_selection.RandomizedSearchCV(ensemble.AdaBoostClassifier(), verbose= 2, param_distributions=tuned_parameters, n_iter=12)
ada_search.fit(x, y)
adal_search.fit(xl, y)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   3.3s
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.7s remaining:    0.0s
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   3.3s
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   3.3s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   6.7s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   6.6s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   6.9s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=  10.9s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=  10.9s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=  11.4s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=  22.3s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=  22.3s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=  21.6s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   3.3s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   3.5s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   3.3s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   6.6s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   6.6s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   6.5s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=  10.8s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=  10.9s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=  10.9s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=  22.3s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=  21.3s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=  21.5s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   3.3s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   3.3s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   3.3s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   6.6s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   6.5s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   6.5s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=  10.7s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=  10.8s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=  10.8s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=  21.5s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=  21.9s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=  21.6s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  7.0min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   0.3s
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   0.3s
# [CV] n_estimators=15, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=15, learning_rate=0.5, total=   0.3s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   0.7s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   0.7s
# [CV] n_estimators=30, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=30, learning_rate=0.5, total=   0.6s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.1s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.1s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.1s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.2s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.3s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.3s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   0.3s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   0.3s
# [CV] n_estimators=15, learning_rate=0.75 .............................
# [CV] .............. n_estimators=15, learning_rate=0.75, total=   0.3s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   0.6s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   0.6s
# [CV] n_estimators=30, learning_rate=0.75 .............................
# [CV] .............. n_estimators=30, learning_rate=0.75, total=   0.6s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=   1.1s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=   1.1s
# [CV] n_estimators=50, learning_rate=0.75 .............................
# [CV] .............. n_estimators=50, learning_rate=0.75, total=   1.1s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=   2.3s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=   2.3s
# [CV] n_estimators=100, learning_rate=0.75 ............................
# [CV] ............. n_estimators=100, learning_rate=0.75, total=   2.3s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   0.3s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   0.3s
# [CV] n_estimators=15, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=15, learning_rate=1.0, total=   0.3s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   0.7s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   0.7s
# [CV] n_estimators=30, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=30, learning_rate=1.0, total=   0.7s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.4s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.2s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.2s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:   53.4s finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#           fit_params={}, iid=True, n_iter=12, n_jobs=1,
#           param_distributions={'n_estimators': [15, 30, 50, 100], 'learning_rate': [0.5, 0.75, 1.0]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
print("Non LDA Report:")
report(ada_search)
print("LDA Report:")
report(adal_search)
# Out:
# Non LDA Report:
# Best parameters set found on development set:
# {'n_estimators': 100, 'learning_rate': 0.5}
#
# Grid scores on development set:
#
# 0.520 (+/-0.065) for {'n_estimators': 15, 'learning_rate': 0.5}
# 0.524 (+/-0.064) for {'n_estimators': 30, 'learning_rate': 0.5}
# 0.528 (+/-0.061) for {'n_estimators': 50, 'learning_rate': 0.5}
# 0.531 (+/-0.060) for {'n_estimators': 100, 'learning_rate': 0.5}
# 0.522 (+/-0.063) for {'n_estimators': 15, 'learning_rate': 0.75}
# 0.526 (+/-0.061) for {'n_estimators': 30, 'learning_rate': 0.75}
# 0.530 (+/-0.059) for {'n_estimators': 50, 'learning_rate': 0.75}
# 0.531 (+/-0.059) for {'n_estimators': 100, 'learning_rate': 0.75}
# 0.523 (+/-0.058) for {'n_estimators': 15, 'learning_rate': 1.0}
# 0.526 (+/-0.052) for {'n_estimators': 30, 'learning_rate': 1.0}
# 0.529 (+/-0.055) for {'n_estimators': 50, 'learning_rate': 1.0}
# 0.530 (+/-0.053) for {'n_estimators': 100, 'learning_rate': 1.0}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   43.0s remaining:  1.1min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   52.1s finished
# Cross-Validated F1-Score: 0.61 (+/- 0.09)
#
# LDA Report:
# Best parameters set found on development set:
# {'n_estimators': 15, 'learning_rate': 0.75}
#
# Grid scores on development set:
#
# 0.569 (+/-0.017) for {'n_estimators': 15, 'learning_rate': 0.5}
# 0.575 (+/-0.004) for {'n_estimators': 30, 'learning_rate': 0.5}
# 0.572 (+/-0.009) for {'n_estimators': 50, 'learning_rate': 0.5}
# 0.572 (+/-0.009) for {'n_estimators': 100, 'learning_rate': 0.5}
# 0.575 (+/-0.006) for {'n_estimators': 15, 'learning_rate': 0.75}
# 0.572 (+/-0.012) for {'n_estimators': 30, 'learning_rate': 0.75}
# 0.572 (+/-0.012) for {'n_estimators': 50, 'learning_rate': 0.75}
# 0.572 (+/-0.012) for {'n_estimators': 100, 'learning_rate': 0.75}
# 0.572 (+/-0.012) for {'n_estimators': 15, 'learning_rate': 1.0}
# 0.572 (+/-0.012) for {'n_estimators': 30, 'learning_rate': 1.0}
# 0.572 (+/-0.011) for {'n_estimators': 50, 'learning_rate': 1.0}
# 0.572 (+/-0.011) for {'n_estimators': 100, 'learning_rate': 1.0}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    8.0s remaining:   12.1s
# Cross-Validated F1-Score: 0.65 (+/- 0.08)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   16.3s finished

# %%
tuned_parameters = {'C': [10, 1, 0.1, 0.01]}
lr_search = model_selection.RandomizedSearchCV(linear_model.LogisticRegression(), verbose= 2, param_distributions=tuned_parameters, n_iter=4)
lrl_search = model_selection.RandomizedSearchCV(linear_model.LogisticRegression(), verbose= 2, param_distributions=tuned_parameters, n_iter=4)
lr_search.fit(x, y)
lrl_search.fit(xl, y)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=  41.3s
# [CV] C=10 ............................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   41.3s remaining:    0.0s
# [CV] ............................................. C=10, total=  31.7s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=  33.7s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=  29.2s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=  23.9s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=  28.0s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=  15.7s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=  15.3s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=  14.9s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   8.2s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   7.2s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   8.8s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  4.3min finished
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=1 .............................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=   0.0s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=   0.0s
# [CV] C=0.1 ...........................................................
# [CV] ............................................ C=0.1, total=   0.0s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   0.0s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   0.0s
# [CV] C=0.01 ..........................................................
# [CV] ........................................... C=0.01, total=   0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.5s finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           fit_params={}, iid=True, n_iter=4, n_jobs=1,
#           param_distributions={'C': [10, 1, 0.1, 0.01]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
print("Non LDA Report:")
report(lr_search)
print("LDA Report:")
report(lrl_search)
# Out:
# Non LDA Report:
# Best parameters set found on development set:
# {'C': 0.01}
#
# Grid scores on development set:
#
# 0.516 (+/-0.071) for {'C': 10}
# 0.517 (+/-0.071) for {'C': 1}
# 0.522 (+/-0.061) for {'C': 0.1}
# 0.528 (+/-0.055) for {'C': 0.01}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   22.2s remaining:   33.4s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   31.3s finished
# Cross-Validated F1-Score: 0.58 (+/- 0.08)
#
# LDA Report:
# Best parameters set found on development set:
# {'C': 0.01}
#
# Grid scores on development set:
#
# 0.576 (+/-0.010) for {'C': 10}
# 0.576 (+/-0.010) for {'C': 1}
# 0.576 (+/-0.010) for {'C': 0.1}
# 0.576 (+/-0.009) for {'C': 0.01}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    7.4s remaining:   11.1s
# Cross-Validated F1-Score: 0.67 (+/- 0.04)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   15.1s finished

# %%
tuned_parameters = {'kernel': ['rbf'], 'C': [0.1, 0.3, 0.5, 0.7, 1], 'gamma': ['auto']}
svm_search = model_selection.RandomizedSearchCV(svm.SVC(), verbose= 2, param_distributions=tuned_parameters, n_iter=5)
svm_search.fit(xl, y)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.8min remaining:    0.0s
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.3min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.3min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.3min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.4min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.5min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.4min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.6min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 44.4min finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#           fit_params={}, iid=True, n_iter=5, n_jobs=1,
#           param_distributions={'kernel': ['rbf'], 'C': [0.1, 0.3, 0.5, 0.7, 1], 'gamma': ['auto']},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
report(svm_search)
# Out:
# Best parameters set found on development set:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.5}
#
# Grid scores on development set:
#
# 0.574 (+/-0.008) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.1}
# 0.574 (+/-0.008) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.3}
# 0.574 (+/-0.008) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.5}
# 0.574 (+/-0.008) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.7}
# 0.574 (+/-0.008) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 1}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed: 72.3min remaining: 108.5min
# Cross-Validated F1-Score: 0.62 (+/- 0.08)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed: 73.4min finished

# %% [markdown]
# Try to add 'propertyzoningdesc' back which has 2000 unique values

# %%
xl_new = pd.read_csv("./data/sign/df_lda_sign_2000.csv", index_col=0, low_memory=False)

# %%
tuned_parameters = {'n_estimators': [50, 100, 150, 200], 'learning_rate': [0.5, 1.0, 1.5]}
ada_search_new = model_selection.RandomizedSearchCV(ensemble.AdaBoostClassifier(), verbose= 2, param_distributions=tuned_parameters, n_iter=12)
ada_search_new.fit(xl_new, y)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.2s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.1s
# [CV] n_estimators=50, learning_rate=0.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=0.5, total=   1.1s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.3s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.3s
# [CV] n_estimators=100, learning_rate=0.5 .............................
# [CV] .............. n_estimators=100, learning_rate=0.5, total=   2.3s
# [CV] n_estimators=150, learning_rate=0.5 .............................
# [CV] .............. n_estimators=150, learning_rate=0.5, total=   3.4s
# [CV] n_estimators=150, learning_rate=0.5 .............................
# [CV] .............. n_estimators=150, learning_rate=0.5, total=   3.6s
# [CV] n_estimators=150, learning_rate=0.5 .............................
# [CV] .............. n_estimators=150, learning_rate=0.5, total=   3.5s
# [CV] n_estimators=200, learning_rate=0.5 .............................
# [CV] .............. n_estimators=200, learning_rate=0.5, total=   4.6s
# [CV] n_estimators=200, learning_rate=0.5 .............................
# [CV] .............. n_estimators=200, learning_rate=0.5, total=   4.6s
# [CV] n_estimators=200, learning_rate=0.5 .............................
# [CV] .............. n_estimators=200, learning_rate=0.5, total=   4.9s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.0 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.0, total=   1.1s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.3s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.3s
# [CV] n_estimators=100, learning_rate=1.0 .............................
# [CV] .............. n_estimators=100, learning_rate=1.0, total=   2.3s
# [CV] n_estimators=150, learning_rate=1.0 .............................
# [CV] .............. n_estimators=150, learning_rate=1.0, total=   3.4s
# [CV] n_estimators=150, learning_rate=1.0 .............................
# [CV] .............. n_estimators=150, learning_rate=1.0, total=   3.4s
# [CV] n_estimators=150, learning_rate=1.0 .............................
# [CV] .............. n_estimators=150, learning_rate=1.0, total=   3.4s
# [CV] n_estimators=200, learning_rate=1.0 .............................
# [CV] .............. n_estimators=200, learning_rate=1.0, total=   4.9s
# [CV] n_estimators=200, learning_rate=1.0 .............................
# [CV] .............. n_estimators=200, learning_rate=1.0, total=   4.8s
# [CV] n_estimators=200, learning_rate=1.0 .............................
# [CV] .............. n_estimators=200, learning_rate=1.0, total=   4.7s
# [CV] n_estimators=50, learning_rate=1.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.5, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.5, total=   1.1s
# [CV] n_estimators=50, learning_rate=1.5 ..............................
# [CV] ............... n_estimators=50, learning_rate=1.5, total=   1.1s
# [CV] n_estimators=100, learning_rate=1.5 .............................
# [CV] .............. n_estimators=100, learning_rate=1.5, total=   2.3s
# [CV] n_estimators=100, learning_rate=1.5 .............................
# [CV] .............. n_estimators=100, learning_rate=1.5, total=   2.3s
# [CV] n_estimators=100, learning_rate=1.5 .............................
# [CV] .............. n_estimators=100, learning_rate=1.5, total=   2.3s
# [CV] n_estimators=150, learning_rate=1.5 .............................
# [CV] .............. n_estimators=150, learning_rate=1.5, total=   3.5s
# [CV] n_estimators=150, learning_rate=1.5 .............................
# [CV] .............. n_estimators=150, learning_rate=1.5, total=   3.4s
# [CV] n_estimators=150, learning_rate=1.5 .............................
# [CV] .............. n_estimators=150, learning_rate=1.5, total=   3.5s
# [CV] n_estimators=200, learning_rate=1.5 .............................
# [CV] .............. n_estimators=200, learning_rate=1.5, total=   4.6s
# [CV] n_estimators=200, learning_rate=1.5 .............................
# [CV] .............. n_estimators=200, learning_rate=1.5, total=   4.6s
# [CV] n_estimators=200, learning_rate=1.5 .............................
# [CV] .............. n_estimators=200, learning_rate=1.5, total=   4.6s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  2.3min finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None),
#           fit_params={}, iid=True, n_iter=12, n_jobs=1,
#           param_distributions={'n_estimators': [50, 100, 150, 200], 'learning_rate': [0.5, 1.0, 1.5]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
print("LDA Report:")
report(ada_search_new)
# Out:
# LDA Report:
# Best parameters set found on development set:
# {'n_estimators': 150, 'learning_rate': 1.0}
#
# Grid scores on development set:
#
# 0.592 (+/-0.004) for {'n_estimators': 50, 'learning_rate': 0.5}
# 0.592 (+/-0.004) for {'n_estimators': 100, 'learning_rate': 0.5}
# 0.592 (+/-0.004) for {'n_estimators': 150, 'learning_rate': 0.5}
# 0.592 (+/-0.004) for {'n_estimators': 200, 'learning_rate': 0.5}
# 0.592 (+/-0.004) for {'n_estimators': 50, 'learning_rate': 1.0}
# 0.595 (+/-0.008) for {'n_estimators': 100, 'learning_rate': 1.0}
# 0.595 (+/-0.008) for {'n_estimators': 150, 'learning_rate': 1.0}
# 0.594 (+/-0.009) for {'n_estimators': 200, 'learning_rate': 1.0}
# 0.591 (+/-0.005) for {'n_estimators': 50, 'learning_rate': 1.5}
# 0.594 (+/-0.009) for {'n_estimators': 100, 'learning_rate': 1.5}
# 0.593 (+/-0.007) for {'n_estimators': 150, 'learning_rate': 1.5}
# 0.593 (+/-0.007) for {'n_estimators': 200, 'learning_rate': 1.5}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:   12.8s remaining:   19.3s
# Cross-Validated F1-Score: 0.67 (+/- 0.04)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   21.3s finished

# %%
tuned_parameters = {'C': [0.1, 1, 10, 100, 1000]}
lr_search_new = model_selection.RandomizedSearchCV(linear_model.LogisticRegression(), verbose= 2, param_distributions=tuned_parameters, n_iter=4)
lr_search_new.fit(xl_new, y)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=1 .............................................................
# [CV] .............................................. C=1, total=   0.0s
# [CV] C=1000 ..........................................................
# [CV] ........................................... C=1000, total=   0.0s
# [CV] C=1000 ..........................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] ........................................... C=1000, total=   0.0s
# [CV] C=1000 ..........................................................
# [CV] ........................................... C=1000, total=   0.0s
# [CV] C=100 ...........................................................
# [CV] ............................................ C=100, total=   0.0s
# [CV] C=100 ...........................................................
# [CV] ............................................ C=100, total=   0.0s
# [CV] C=100 ...........................................................
# [CV] ............................................ C=100, total=   0.0s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [CV] C=10 ............................................................
# [CV] ............................................. C=10, total=   0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.5s finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           fit_params={}, iid=True, n_iter=4, n_jobs=1,
#           param_distributions={'C': [0.1, 1, 10, 100, 1000]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
report(lr_search_new)
# Out:
# LDA Report:
# Best parameters set found on development set:
# {'C': 1}
#
# Grid scores on development set:
#
# 0.594 (+/-0.009) for {'C': 1}
# 0.594 (+/-0.009) for {'C': 1000}
# 0.594 (+/-0.009) for {'C': 100}
# 0.594 (+/-0.009) for {'C': 10}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:    7.4s remaining:   11.2s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:   15.3s finished
# Cross-Validated F1-Score: 0.67 (+/- 0.03)

# %%
tuned_parameters = {'kernel': ['rbf'], 'C': [0.1, 0.3, 0.5, 0.7, 1], 'gamma': ['auto']}
svm_search_new = model_selection.RandomizedSearchCV(svm.SVC(), verbose= 2, param_distributions=tuned_parameters, n_iter=5)
svm_search_new.fit(xl_new, y)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 1.9min
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.6min remaining:    0.0s
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 1.9min
# [CV] kernel=rbf, gamma=auto, C=0.1 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.1, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.3 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.3, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.0min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=0.5 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.5, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=0.7 ...................................
# [CV] .................... kernel=rbf, gamma=auto, C=0.7, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.1min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.2min
# [CV] kernel=rbf, gamma=auto, C=1 .....................................
# [CV] ...................... kernel=rbf, gamma=auto, C=1, total= 2.3min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 41.3min finished
# RandomizedSearchCV(cv=None, error_score='raise',
#           estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#           fit_params={}, iid=True, n_iter=5, n_jobs=1,
#           param_distributions={'kernel': ['rbf'], 'C': [0.1, 0.3, 0.5, 0.7, 1], 'gamma': ['auto']},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=2)

# %%
report(svm_search_new)
# Out:
# Best parameters set found on development set:
# {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.7}
#
# Grid scores on development set:
#
# 0.593 (+/-0.005) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.1}
# 0.593 (+/-0.005) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.3}
# 0.593 (+/-0.006) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.5}
# 0.593 (+/-0.006) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 0.7}
# 0.593 (+/-0.006) for {'kernel': 'rbf', 'gamma': 'auto', 'C': 1}
#
# Detailed classification report:
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed: 74.3min remaining: 111.5min
# Cross-Validated F1-Score: 0.62 (+/- 0.08)
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed: 75.6min finished

# %% [markdown]
# # 5. Modeling for Logerror

# %% [markdown]
# ### 5.1. Data Split

# %%
d = pd.read_csv('./data/logerror/data_transformed.csv', index_col=0, low_memory=False)
y = d.logerror
#Use Scaled data
x = d.drop(['logerror'], axis=1)
#Use Scalded and PCA data
xp = pd.read_csv("./data/logerror/df_pca.csv", index_col=0, low_memory=False)

# %%
train_id, test_id = model_selection.train_test_split(d.index, test_size=0.2)

# %%
x_train = x.loc[train_id]
x_test = x.loc[test_id]
y_train = y.loc[train_id]
y_test = y.loc[test_id]
xp_train = xp.loc[train_id]
xp_test = xp.loc[test_id]

# %% [markdown]
# ### 5.2. Fit Model

# %% [markdown]
# Linear Regression

# %%
lr = linear_model.LinearRegression()
lrp = linear_model.LinearRegression()

# %%
lr.fit(x_train, y_train)
lrp.fit(xp_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("Fitted model")
y_fit = lr.predict(x_train)
g = sns.jointplot(y_train, y_fit, kind="reg", size=7);
g.set_axis_labels(xlabel="logerror",ylabel="fitted logerror");
# Out:
# Fitted model

# %%
print('Intercept:',lr.intercept_)
print('Coefficients:')
coefs_df = pd.DataFrame(index=x_train.columns,data=lr.coef_, columns=['coef']);
coefs_df.sort_values('coef', ascending=False).plot.barh(figsize=(20, 100));
# Out:
# Intercept: -155767381.539
# Coefficients:

# %%
scores = model_selection.cross_val_score(lr, x, y, cv=5, scoring='neg_mean_absolute_error')
scoresp = model_selection.cross_val_score(lrp, xp, y, cv=5, scoring='neg_mean_absolute_error')
print("Non PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std()))
print("PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scoresp.mean(), scoresp.std()))
# Out:
# Non PCA Cross-Validated MAE Score: -380895441853.278 (+/- 304028654177.877)
# PCA Cross-Validated MAE Score: -820026626811.432 (+/- 582319092088.713)

# %% [markdown]
# Lasso Regression

# %%
lar = linear_model.Lasso(alpha=0.001)
larp = linear_model.Lasso(alpha=0.001)

# %%
lar.fit(x_train, y_train)
larp.fit(xp_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
print('Intercept:',lar.intercept_)
print('Coefficients:')
coefs_df = pd.DataFrame(index=x_train.columns,data=lar.coef_, columns=['coef']);
coefs_df.sort_values('coef', ascending=False).plot.barh(figsize=(20, 100));
# Out:
# Intercept: 0.00935053782426
# Coefficients:

# %% [markdown]
# Features related with tax, square size and land use have higher coefficients.

# %%
scores = model_selection.cross_val_score(lar, x, y, cv=5, scoring = 'neg_mean_absolute_error')
scoresp = model_selection.cross_val_score(larp, xp, y, cv=5, scoring = 'neg_mean_absolute_error')
print("Non PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std()))
print("PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scoresp.mean(), scoresp.std()))
# Out:
# Non PCA Cross-Validated MAE Score: -0.053 (+/- 0.008)
# PCA Cross-Validated MAE Score: -0.053 (+/- 0.008)

# %% [markdown]
# Adaboost

# %%
ada = ensemble.AdaBoostRegressor()
adap = ensemble.AdaBoostRegressor()

# %%
scores = model_selection.cross_val_score(ada, x, y, cv=5, scoring='neg_mean_absolute_error')
scoresp = model_selection.cross_val_score(adap, xp, y, cv=5, scoring='neg_mean_absolute_error')
print("Non PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std()))
print("PCA Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scoresp.mean(), scoresp.std()))
# Out:
# Non PCA Cross-Validated MAE Score: -0.059 (+/- 0.008)
# PCA Cross-Validated MAE Score: -0.059 (+/- 0.008)

# %% [markdown]
# ### 5.3. Parameter Tunning & Cross Validation

# %%
def report(reg):
    print("Best parameters set found on development set:")
    print(reg.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = reg.cv_results_['mean_test_score']
    stds = reg.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, reg.cv_results_['params']):
        print(("%0.3f (+/-%0.03f) for %r")
              % (mean, std * 2, params))
    print()
    print("Detailed regression report:")
    print()
    scores = model_selection.cross_val_score(reg.best_estimator_, x, y, cv=5, verbose=1, n_jobs=5, scoring="neg_mean_absolute_error")
    print("Cross-Validated MAE Score: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() ))
    print()

# %%
tuned_parameters = {'alpha': [0.0001, 0.001, 0.01, 0.1]}
lar_search = model_selection.RandomizedSearchCV(linear_model.Lasso(), verbose= 2, param_distributions=tuned_parameters, n_iter=4)
lar_search.fit(xp, y)
report(lar_search)

# %%
tuned_parameters = {'n_estimators': [50, 100, 150, 200], 'learning_rate': [0.5, 1.0, 1.5]}
ada_search = model_selection.RandomizedSearchCV(ensemble.AdaBoostRegressor(), verbose= 2, param_distributions=tuned_parameters, n_iter=12)
ada_search.fit(xp, y)
report(ada_search)
